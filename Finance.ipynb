# %%
import yfinance as fin
import pandas as pd

# %%
getGoogleInfo = fin.Ticker("GOOGL")

# %%
print(getGoogleInfo.info)
# Out:
# {'address1': '1600 Amphitheatre Parkway', 'city': 'Mountain View', 'state': 'CA', 'zip': '94043', 'country': 'United States', 'phone': '650 253 0000', 'website': 'https://abc.xyz', 'industry': 'Internet Content & Information', 'industryKey': 'internet-content-information', 'industryDisp': 'Internet Content & Information', 'sector': 'Communication Services', 'sectorKey': 'communication-services', 'sectorDisp': 'Communication Services', 'longBusinessSummary': 'Alphabet Inc. offers various products and platforms in the United States, Europe, the Middle East, Africa, the Asia-Pacific, Canada, and Latin America. It operates through Google Services, Google Cloud, and Other Bets segments. The Google Services segment provides products and services, including ads, Android, Chrome, devices, Gmail, Google Drive, Google Maps, Google Photos, Google Play, Search, and YouTube. It is also involved in the sale of apps and in-app purchases and digital content in the Google Play and YouTube; and device
# ...

# %%
print('Company sector:',getGoogleInfo.info['sector'])
print('Price Earning Ratio:',getGoogleInfo.info['trailingPE'])
print('Company Beta',getGoogleInfo.info['beta'])
# Out:
# Company sector: Communication Services
# Price Earning Ratio: 24.577585
# Company Beta 1.058

# %%
for attribute in getGoogleInfo.info.keys():
    print(attribute)
# Out:
# address1
# city
# state
# zip
# country
# phone
# website
# industry
# industryKey
# industryDisp
# sector
# sectorKey
# sectorDisp
# longBusinessSummary
# fullTimeEmployees
# companyOfficers
# auditRisk
# boardRisk
# compensationRisk
# shareHolderRightsRisk
# overallRisk
# governanceEpochDate
# compensationAsOfEpochDate
# maxAge
# priceHint
# previousClose
# open
# dayLow
# dayHigh
# regularMarketPreviousClose
# regularMarketOpen
# regularMarketDayLow
# regularMarketDayHigh
# beta
# trailingPE
# forwardPE
# volume
# regularMarketVolume
# averageVolume
# averageVolume10days
# averageDailyVolume10Day
# bidSize
# askSize
# marketCap
# fiftyTwoWeekLow
# fiftyTwoWeekHigh
# priceToSalesTrailing12Months
# fiftyDayAverage
# twoHundredDayAverage
# currency
# enterpriseValue
# profitMargins
# floatShares
# sharesOutstanding
# sharesShort
# sharesShortPriorMonth
# sharesShortPreviousMonthDate
# dateShortInterest
# sharesPercentSharesOut
# heldPercentInsiders
# heldPercentInstitutions
# ...

# %%
pd.set_option('display.max_rows',None)
print(getGoogleInfo.history(period='max'))
# Out:
# /home/nikhilagarwal/.local/lib/python3.12/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
#                                  Open        High         Low       Close  \
# Date
# 2004-08-19 00:00:00-04:00    2.502503    2.604104    2.401401    2.511011
# 2004-08-20 00:00:00-04:00    2.527778    2.729730    2.515015    2.710460
# 2004-08-23 00:00:00-04:00    2.771522    2.839840    2.728979    2.737738
# 2004-08-24 00:00:00-04:00    2.783784    2.792793    2.591842    2.624374
# 2004-08-25 00:00:00-04:00    2.626627    2.702703    2.599600    2.652653
# 2004-08-26 00:00:00-04:00    2.626376    2.701451    2.619119    2.700450
# 2004-08-27 00:00:00-04:00    2.705205    2.718218    2.644895    2.656406
# 2004-08-30 00:00:00-04:00    2.634635    2.639890    2.552803    2.552803
# ...

# %%
print(getGoogleInfo.history(period='6mo'))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-08-22 00:00:00-04:00  128.509995  130.279999  128.320007  129.080002
# 2023-08-23 00:00:00-04:00  130.179993  133.410004  129.869995  132.369995
# 2023-08-24 00:00:00-04:00  133.949997  134.250000  129.570007  129.779999
# 2023-08-25 00:00:00-04:00  129.539993  130.759995  127.250000  129.880005
# 2023-08-28 00:00:00-04:00  131.309998  132.539993  130.139999  131.009995
# 2023-08-29 00:00:00-04:00  132.240005  136.570007  132.240005  134.570007
# 2023-08-30 00:00:00-04:00  134.779999  136.279999  134.070007  135.880005
# 2023-08-31 00:00:00-04:00  136.009995  138.000000  135.789993  136.169998
# 2023-09-01 00:00:00-04:00  137.460007  137.460007  134.850006  135.660004
# 2023-09-05 00:00:00-04:00  135.440002  136.419998  134.580002  135.770004
# 2023-09-06 00:00:00-04:00  136.020004  136.529999  133.669998  134.460007
# 2023-09-07 00:00:00-04:00  133.589996  135.580002  132.949997  135.259995
# ...

# %%
print(getGoogleInfo.history(period='1wk'))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-15 00:00:00-05:00  143.139999  143.520004  140.460007  142.770004
# 2024-02-16 00:00:00-05:00  142.990005  143.190002  140.139999  140.520004
# 2024-02-20 00:00:00-05:00  139.660004  142.080002  139.490005  141.119995
# 2024-02-21 00:00:00-05:00  141.449997  142.690002  140.679993  142.550003
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-02-15 00:00:00-05:00  37590700        0.0           0.0
# 2024-02-16 00:00:00-05:00  31451100        0.0           0.0
# 2024-02-20 00:00:00-05:00  25144700        0.0           0.0
# 2024-02-21 00:00:00-05:00  23223300        0.0           0.0
# /home/nikhilagarwal/.local/lib/python3.12/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
# ...

# %%
getGoogleInfo.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)

# %%
getGoogleInfo.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.00279
# institutionsPercentHeld          0.80497
# institutionsFloatPercentHeld     0.80722
# institutionsCount             5579.00000

# %%
getGoogleInfo.get_shares_full(start = '2024-01-01',end = None)
# Out:
# 2024-01-02 00:00:00-05:00    12566800384
# 2024-01-03 00:00:00-05:00    12572800000
# 2024-01-04 00:00:00-05:00    12575299584
# 2024-01-05 00:00:00-05:00    12585299968
# 2024-01-05 00:00:00-05:00    12808599552
# 2024-01-06 00:00:00-05:00    12525100032
# 2024-01-06 00:00:00-05:00    12586000384
# 2024-01-09 00:00:00-05:00    12585700352
# 2024-01-10 00:00:00-05:00    12581799936
# 2024-01-11 00:00:00-05:00    12576799744
# 2024-01-12 00:00:00-05:00    12580899840
# 2024-01-12 00:00:00-05:00    12591800320
# 2024-01-13 00:00:00-05:00    12578199552
# 2024-01-16 00:00:00-05:00    12579800064
# 2024-01-17 00:00:00-05:00    12579900416
# 2024-01-18 00:00:00-05:00    12573500416
# 2024-01-19 00:00:00-05:00    12576300032
# 2024-01-20 00:00:00-05:00    12577800192
# 2024-01-23 00:00:00-05:00    12583400448
# 2024-01-24 00:00:00-05:00    12579900416
# 2024-01-25 00:00:00-05:00    12579500032
# 2024-01-26 00:00:00-05:00    12583100416
# 2024-01-27 00:00:00-05:00    12576900096
# ...

# %%
getGoogleInfo.cash_flow
# Out:
#                                                     2023-12-31     2022-12-31  \
# Free Cash Flow                                   69495000000.0  60010000000.0
# Repurchase Of Capital Stock                     -61504000000.0 -59296000000.0
# Repayment Of Debt                               -11550000000.0 -54068000000.0
# Issuance Of Debt                                 10790000000.0  52872000000.0
# Capital Expenditure                             -32251000000.0 -31485000000.0
# Income Tax Paid Supplemental Data                19164000000.0  18892000000.0
# End Cash Position                                24048000000.0  21879000000.0
# Beginning Cash Position                          21879000000.0  20945000000.0
# Effect Of Exchange Rate Changes                   -421000000.0   -506000000.0
# Changes In Cash                                   2590000000.0   1440000000.0
# Financing Cash Flow                             -72093000000.0 -69757000000.0
# ...

# %%
getGoogleInfo.news
# Out:
# [{'uuid': '2a43ca63-abdd-3e15-906e-926eae05cf21',
#   'title': 'Exclusive-Reddit in AI content licensing deal with Google, sources say',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/exclusive-reddit-ai-content-licensing-041012378.html',
#   'providerPublishTime': 1708575012,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Ak.skCPLGF.S1onlb83_AA--~B/aD01NDg7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/874bd689ca171d82b8c5a71badd7ab2c',
#      'width': 800,
#      'height': 548,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/zg49w.4zknXG0G3_CQKGNw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/reuters-finance.com/874bd689ca171d82b8c5a71badd7ab2c',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['GOOG']},
#  {'uuid': '43707d22-5538-380b-a410-7225b4f00009',
# ...

# %%
getGoogleInfo.income_stmt
# Out:
#                                                         2023-12-31  \
# Tax Effect Of Unusual Items                           -286479000.0
# Tax Rate For Calcs                                           0.139
# Normalized EBITDA                                   100032000000.0
# Total Unusual Items                                  -2061000000.0
# Total Unusual Items Excluding Goodwill               -2061000000.0
# Net Income From Continuing Operation Net Minori...   73795000000.0
# Reconciled Depreciation                              11946000000.0
# Reconciled Cost Of Revenue                          133332000000.0
# EBITDA                                               97971000000.0
# EBIT                                                 86025000000.0
# Net Interest Income                                   3557000000.0
# Interest Expense                                       308000000.0
# Interest Income                                       3865000000.0
# ...
